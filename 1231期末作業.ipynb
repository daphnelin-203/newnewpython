# %%
import requests
res = requests.get('https://www.tmall.hk/wh/tmall/import/act/jhb')

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '\r\n\r\n\n\n\n\n<!DOCTYPE HTML>\n<html >\n<head>\n  \n  \n  \n  \n  \n  \n  \n  <meta charset="utf-8"/>\n<meta name="renderer" content="webkit"/>\n<meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n<link rel="dns-prefetch" href="//g.alicdn.com"/>\n<link rel="dns-prefetch" href="//img.alicdn.com"/>\n<link rel="dns-prefetch" href="//gm.mmstat.com"/>\n<link rel="dns-prefetch" href="//ald.taobao.com"/>\n<link rel="dns-prefetch" href="//bar.tmall.com"/>\n<link href="//img.alicdn.com/tfs/TB1XlF3RpXXXXc6XXXXXXXXXXXX-16-16.png" rel="shortcut icon" type="image/x-icon"/>\n<link title="天猫Tmall.com" href="//g.alicdn.com/mui/global/1.2.35/file/search.xml" type="application/opensearchdescription+xml" rel="search"/>\n<meta name="spm-id" content="a2231.7747006"/>\n\n<title>挑战全球尖货榜-理想生活上天猫</title>\n<script>\n    window.g_config = {\n        devId: \'pc\',\n        headerVersion: \'1.4.0\',\n        loadModulesLater: true,\n        \n        \n        sl: \'node\'\n    };\n</script>\n\n\n<base t
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(res.text, 'lxml')

# %%
soup.select_one('#J_dynamic_data').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-8a5452a42c83> in <module>()
# ----> 1 soup.select_one('#J_dynamic_data').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
import json
jd = json.loads(soup.select_one('#J_dynamic_data').text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2c3e4d2be556> in <module>()
#       1 import json
# ----> 2 jd = json.loads(soup.select_one('#J_dynamic_data').text)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
jd
# Out:
# {'dLife': {'icon': '',
#   'title': '生活/数码',
#   'navKey': [{'href': '//list.tmall.hk/search_product.htm?cat=52792006&sort=s&acm=lb-zebra-34359-425773.1003.8.519269&style=g&search_condition=7&q=%C2%CB%CB%AE%BA%F8&industryCatId=56446039&spm=a220m.1000858.0.0.UoHkwP&from=tmhk_1_rightnav&scm=1003.8.lb-zebra-34359-425773.ITEM_14515144531204_519269&tmhkmain=1#J_crumbs',
#     'title': '滤水壶/滤芯'},
#    {'href': '//list.tmall.hk/search_product.htm?_input_charset=utf-8&area=b2c&auction_tag=13186&acm=lb-zebra-34359-425773.1003.8.519269&q=%E6%89%AB%E5%9C%B0%E6%9C%BA%E5%99%A8%E4%BA%BA&spm=a2222.7688326.z6654ak.c543&code=gbk&abtest=null&search_type=0&scm=1003.8.lb-zebra-34359-425773.ITEM_14455542348811_519269',
#     'title': '扫地机器人'},
#    {'href': '//list.tmall.hk/search_product.htm?auction_tag=13186&area=b2c&acm=lb-zebra-34359-425773.1003.8.519269&q=%B1%A3%CE%C2%B1%AD&spm=a2222.1279144.1998170891.216.MtEGPa&code=gbk&scm=1003.8.lb-zebra-34359-425773.ITEM_14455553891282_519269',
# ...
